# %%
import random
import numpy as np
from evaluation_method import evaluate

random.seed(0)
prediction = np.array(random.choices(["dog", "cat", "human"], k = 100))
actual = np.array(random.choices(["dog", "cat", "human"], k = 100))

# %%
evaluate(actual, prediction, level = 'micro', draw = True)
evaluate(actual, prediction, level = 'macro')
evaluate(actual, prediction, level = 'weighted')
# Out:
# micro
#  Accuracy: 27.0, Recall: 27.0, Precision: 27.0, F1-Score:27.0
# macro
#  Accuracy: 27.0, Recall: 27.361673414304992, Precision: 29.14943768602305, F1-Score:28.227277030869317
# weighted
#  Accuracy: 27.0, Recall: 27.0, Precision: 30.070713729250315, F1-Score:28.45274634347643
